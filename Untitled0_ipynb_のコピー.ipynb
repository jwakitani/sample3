# %% [markdown]
# <a href="https://colab.research.google.com/github/jwakitani/sample3/blob/main/Untitled0_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 文字列その他

a = 'hello world' ; b = 'hello its \
me '
print( a , b , sep='と\n')

c = a+b
print( c )

c = a*3
print( c )

c = a.upper()
print( 'UPPER: ', c )
c = a.count( 'l' )
print( 'COUNT: ', c)
c = a.find( 'w' )
print('FIND: ', c )

a = '猫と犬はどちらが人間になつくのか'
c = a.replace('猫','うみねこ')
print( a, c )

a = 'hello world \n hello its me'
print( a )

a = '仮想通貨ＢＴＣの現在価格：' + str( 320000) + '円'
print( a )
print( '最初の文字は、' + a[1] )
print( '最後の文字は、' + a[-1] )
print( '２つ目の文字から４つ目の文字は、' + a[1:1+3])

name = 'マナマナ'
age = 32
text = f"名前：{name}, 年齢：{age}"
print( text )


# mathライブラリをインポートしてceil切り上げ, floor切り下げを使う
import math
c = 12.3e-1
print( c , round( c ) , math.ceil( c) , math.floor( c ) )
print( math.pi )
print( math.degrees(math.pi / 2.0) )
val = math.sin( math.pi / 2.0)
print( 'sin(pi/2):', val )

# randomライブラリからrandom()関数のみをインポートする
from random import random
print( random() )
print( random() )
print( random() )




# 複素数の計算
d = (2 + 3j)
e = (1 - 1j)
f = d * e
print( f.real, f.imag )
f = complex(3, 4)
print( f.real, f.imag )
f = complex( "3+4J" )
print( f.real, f.imag )


# 演算子
a = 12
print( 9 < a < 20)
print( a == 12 )
print( a != 11 )
print( a >= 10 )
print( a <= 20 )

print( True and True )
print( True and False )
print( True or False )
print( False or False)

# 型
print( type(1) )
print( type(1.2) )
print( type('aaa') )
print( type([0, 1, 2]) )

# 関数
print( max( 1, 2, 3) )
print( chr(97) )
print( len('Python') )

# val = input('好きな言葉は？：')
# print( val )
# Out:
# hello worldと
# hello its me
# hello worldhello its me
# hello worldhello worldhello world
# UPPER:  HELLO WORLD
# COUNT:  3
# FIND:  6
# 猫と犬はどちらが人間になつくのか うみねこと犬はどちらが人間になつくのか
# hello world
#  hello its me
# 仮想通貨ＢＴＣの現在価格：320000円
# 最初の文字は、想
# 最後の文字は、円
# ２つ目の文字から４つ目の文字は、想通貨
# 名前：マナマナ, 年齢：32
# 1.23 1 2 1
# 3.141592653589793
# 90.0
# sin(pi/2): 1.0
# 0.7901306682526338
# 0.9748511217779784
# 0.2704223220901071
# 5.0 1.0
# 3.0 4.0
# 3.0 4.0
# True
# True
# True
# True
# True
# True
# False
# True
# False
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# 3
# a
# 6

# %% [markdown]
# adding text block
